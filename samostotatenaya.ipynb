# %% [markdown]
# # Самостоятельная работа (задания 4-5)

# %%
from numpy import log, cos

# %% [markdown]
# ## Задание 4.
#
# Вычислите один корень заданного уравнения с помощью программы для компьютера c точностью $10^{-6}$, используя комбинированный мето хорд и касательных.

# %% [markdown]
# ## Задание 5.
#
# Вычислите один корень заданного уравнения с точностью $10^{-6}$, используя один из инструментальных пакетов.
